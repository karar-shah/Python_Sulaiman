# %% [markdown]
# # Part-1

# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. It will be easier to inspect this data once we have it in a DataFrame. You can’t even call .head() on these csvs!  How are you supposed to read them?
# ### Using glob, loop through the census files available and load them into DataFrames. Then, concatenate all of those DataFrames together into one DataFrame, called something like us_census.

# %%
glob.glob(r'C:\Users\Karar\OneDrive\Desktop\Fiver\karar\Sulaiman\Python_Sulaiman\Session_6\Pandas\*[0-9]*csv')
# Out:
# ['C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states0.csv',
#  'C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states1.csv',
#  'C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states2.csv',
#  'C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states3.csv',
#  'C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states4.csv',
#  'C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states5.csv',
#  'C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states6.csv',
#  'C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states7.csv',
#  'C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states8.csv',
#  'C:\\Users\\Karar\\OneDrive\\Desktop\\Fiver\\karar\\Sulaiman\\Python_Sulaiman\\Session_6\\Pandas\\states9.csv']

# %%
us_census = pd.concat(map(pd.read_csv, glob.glob(r'C:\Users\Karar\OneDrive\Desktop\Fiver\karar\Sulaiman\Python_Sulaiman\Session_6\Pandas\*[0-9]*csv') ))

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# 0  0.03435374149659865%  $43296.35860306644    2341093M_2489527F
# 1   1.0586826347305378%  $70354.74390243902      384160M_349215F
# 2  0.16763157894736833%  $54207.82095490716    3299088M_3342840F
# 3  0.14686131386861315%  $41935.63396778917    1451913M_1506295F
# 4  0.35141038442336353%  $67264.78230266465  19087135M_19334329F

# %% [markdown]
# ### 3. Look at the .columns and the .dtypes of the us_census DataFrame. Are those datatypes going to hinder you as you try to make histograms?

# %%
us_census.columns , us_census.dtypes
# Out:
# (Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#         'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#        dtype='object'),
#  Unnamed: 0     int64
#  State         object
#  TotalPop       int64
#  Hispanic      object
#  White         object
#  Black         object
#  Native        object
#  Asian         object
#  Pacific       object
#  Income        object
#  GenderPop     object
#  dtype: object)

# %% [markdown]
# ### 4 Look at the .head() of the DataFrame so that you can understand why some of these dtypes are objects instead of integers or floats.

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# 0  0.03435374149659865%  $43296.35860306644    2341093M_2489527F
# 1   1.0586826347305378%  $70354.74390243902      384160M_349215F
# 2  0.16763157894736833%  $54207.82095490716    3299088M_3342840F
# 3  0.14686131386861315%  $41935.63396778917    1451913M_1506295F
# 4  0.35141038442336353%  $67264.78230266465  19087135M_19334329F

# %% [markdown]
# ### 5. Use regex to turn the Income column into a format that is ready for conversion into a numerical type.

# %%
us_census.replace('[%,$,M,F]','',regex=True, inplace=True)             #Cleaning values of DataFrame (removing $,%,F,M from values)

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop            Hispanic               White  \
# 0           0     Alabama   4830620  3.7516156462584975     61.878656462585
# 1           1      Alaska    733375   5.909580838323351  60.910179640718574
# 2           2     Arizona   6641928  29.565921052631502  57.120000000000026
# 3           3    Arkansas   2958208   6.215474452554738   71.13781021897813
# 4           4  California  38421464  37.291874687968054   40.21578881677474
#
#                 Black               Native               Asian  \
# 0   31.25297619047618   0.4532312925170065  1.0502551020408146
# 1  2.8485029940119775    16.39101796407186   5.450299401197604
# 2  3.8509868421052658     4.35506578947368   2.876578947368419
# 3  18.968759124087573   0.5229197080291965  1.1423357664233578
# 4   5.677396405391911  0.40529206190713685  13.052234148776776
#
#                Pacific             Income          GenderPop
# 0  0.03435374149659865  43296.35860306644    2341093_2489527
# 1   1.0586826347305378  70354.74390243902      384160_349215
# 2  0.16763157894736833  54207.82095490716    3299088_3342840
# 3  0.14686131386861315  41935.63396778917    1451913_1506295
# 4  0.35141038442336353  67264.78230266465  19087135_19334329

# %% [markdown]
# ### 6. Look at the GenderPop column. We are going to want to separate this into two columns, the Men column, and the Women column.
# ### plit the column into those two new columns using str.split and separating out those results.

# %%
us_census[['MalePop','FemalePop']]=us_census.GenderPop.str.split('_',expand=True)   #Creating 2 seprate columns for M & F population score

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop            Hispanic               White  \
# 0           0     Alabama   4830620  3.7516156462584975     61.878656462585
# 1           1      Alaska    733375   5.909580838323351  60.910179640718574
# 2           2     Arizona   6641928  29.565921052631502  57.120000000000026
# 3           3    Arkansas   2958208   6.215474452554738   71.13781021897813
# 4           4  California  38421464  37.291874687968054   40.21578881677474
#
#                 Black               Native               Asian  \
# 0   31.25297619047618   0.4532312925170065  1.0502551020408146
# 1  2.8485029940119775    16.39101796407186   5.450299401197604
# 2  3.8509868421052658     4.35506578947368   2.876578947368419
# 3  18.968759124087573   0.5229197080291965  1.1423357664233578
# 4   5.677396405391911  0.40529206190713685  13.052234148776776
#
#                Pacific             Income          GenderPop   MalePop  \
# 0  0.03435374149659865  43296.35860306644    2341093_2489527   2341093
# 1   1.0586826347305378  70354.74390243902      384160_349215    384160
# 2  0.16763157894736833  54207.82095490716    3299088_3342840   3299088
# 3  0.14686131386861315  41935.63396778917    1451913_1506295   1451913
# 4  0.35141038442336353  67264.78230266465  19087135_19334329  19087135
#
#   FemalePop
# 0   2489527
# 1    349215
# 2   3342840
# 3   1506295
# 4  19334329

# %% [markdown]
# ### 7. Convert both of the columns into numerical datatypes. There is still an M or an F character in each entry! We should remove those before we convert.

# %%
us_census = us_census.astype('float64', errors='ignore')                   #Changing data dytpe of values form int/str to float

# %%
us_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 5
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  60 non-null     float64
#  1   State       60 non-null     object
#  2   TotalPop    60 non-null     float64
#  3   Hispanic    60 non-null     float64
#  4   White       60 non-null     float64
#  5   Black       60 non-null     float64
#  6   Native      60 non-null     float64
#  7   Asian       60 non-null     float64
#  8   Pacific     55 non-null     float64
#  9   Income      60 non-null     float64
#  10  GenderPop   60 non-null     object
#  11  MalePop     60 non-null     float64
#  12  FemalePop   60 non-null     object
# dtypes: float64(10), object(3)
# memory usage: 6.6+ KB

# %%
us_census.reset_index(drop=True, inplace=True)

# %%
us_census[us_census['FemalePop'] == ''].index
# Out:
# Int64Index([23, 24, 31], dtype='int64')

# %%
us_census['FemalePop'] = us_census['FemalePop'].drop([23, 24, 31], axis=0)

# %%
us_census[us_census['FemalePop'] == ''].index
# Out:
# Int64Index([], dtype='int64')

# %%
us_census['FemalePop'] = us_census['FemalePop'].dropna()

# %%
us_census.dropna(inplace=True)

# %%
us_census['FemalePop'].unique(), len(us_census['FemalePop'].unique())
# Out:
# (array(['2489527', '349215', '3342840', '1506295', '19334329', '1841615',
#         '340810', '10045763', '5123362', '696428', '806083', '6556862',
#         '3333382', '1558931', '2233145', '2364097', '679019', '3455936',
#         '5038598', '2727005', '1536358', '3081445', '939759', '1390901',
#         '670717', '4561386', '1051703', '10131373', '5049925', '5913084',
#         '1942789', '1990780', '6534215', '1869213', '543273', '2455167',
#         '419713', '3331859', '13367298', '1444150', '318031', '4195682',
#         '3497739', '937789', '2890732'], dtype=object),
#  45)

# %%
us_census['FemalePop'] = us_census['FemalePop'].astype(np.float32)

# %%
us_census = us_census.astype(np.float32, errors='ignore')                   #Changing data dytpe of values form int/str to float

# %%
us_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 59
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  52 non-null     float64
#  1   State       52 non-null     object
#  2   TotalPop    52 non-null     float64
#  3   Hispanic    52 non-null     float64
#  4   White       52 non-null     float64
#  5   Black       52 non-null     float64
#  6   Native      52 non-null     float64
#  7   Asian       52 non-null     float64
#  8   Pacific     52 non-null     float64
#  9   Income      52 non-null     float64
#  10  GenderPop   52 non-null     object
#  11  MalePop     52 non-null     float64
#  12  FemalePop   52 non-null     float32
# dtypes: float32(1), float64(10), object(2)
# memory usage: 5.5+ KB

# %% [markdown]
# ### 8. Use matplotlib to make a scatterplot!  plt.scatter(the_women_column, the_income_column) . Remember to call plt.show() to see the graph!

# %%
import matplotlib.pyplot as plt

# %%
# Making scatter plat
plt.figure(figsize=(12,6))
plt.scatter(us_census.FemalePop, us_census.Income)
plt.show()

# %% [markdown]
# ### 9. We can fill in those nans by using pandas’ .fillna() function.You have the TotalPop per state, and you have the Men per state.  As an estimate for the nan values in the Women column, you could use the TotalPop of that state minus the Men for that state.  Print out the Women column after filling the nan values to see if it worked!

# %%
print(us_census['FemalePop']) #To see if there are empty/nan values
us_census['FemalePop'] = us_census.TotalPop - us_census.MalePop  #filling empty cells 
print(us_census['FemalePop']) #To see if empty/nan are filled
# Out:
# 0      2489527.0
# 1       349215.0
# 2      3342840.0
# 3      1506295.0
# 4     19334328.0
# 7      1841615.0
# 9       340810.0
# 10    10045763.0
# 11     5123362.0
# 12     5123362.0
# 13      696428.0
# 14      806083.0
# 15     6556862.0
# 16     3333382.0
# 17     1558931.0
# 18     1558931.0
# 20     2233145.0
# 21     2364097.0
# 22      679019.0
# 25     3455936.0
# 26     5038598.0
# 27     2727005.0
# 28     1536358.0
# 29     3081445.0
# 30     3081445.0
# 32      939759.0
# 33     1390901.0
# 34      670717.0
# 35     4561386.0
# 36     4561386.0
# 37     1051703.0
# 38    10131373.0
# 39     5049925.0
# 41     5913084.0
# 42     5913084.0
# 43     1942789.0
# 44     1990780.0
# 45     6534215.0
# 46     1869213.0
# 47      543273.0
# 48      543273.0
# 49     2455167.0
# 50      419713.0
# 51     3331859.0
# 52    13367298.0
# 53     1444150.0
# 54     1444150.0
# 55      318031.0
# 56     4195682.0
# 57     3497739.0
# 58      937789.0
# 59     2890732.0
# Name: FemalePop, dtype: float32
# 0      2489527.0
# 1       349215.0
# 2      3342840.0
# 3      1506295.0
# 4     19334328.0
# 7      1841615.0
# 9       340810.0
# 10    10045763.0
# 11     5123362.0
# 12     5123362.0
# 13      696428.0
# 14      806083.0
# 15     6556862.0
# 16     3333382.0
# 17     1558931.0
# 18     1558931.0
# 20     2233145.0
# 21     2364097.0
# 22      679019.0
# 25     3455936.0
# 26     5038598.0
# 27     2727005.0
# 28     1536358.0
# 29     3081445.0
# 30     3081445.0
# 32      939759.0
# 33     1390901.0
# 34      670717.0
# 35     4561386.0
# 36     4561386.0
# 37     1051703.0
# 38    10131373.0
# 39     5049925.0
# 41     5913084.0
# 42     5913084.0
# 43     1942789.0
# 44     1990780.0
# 45     6534215.0
# 46     1869213.0
# 47      543273.0
# 48      543273.0
# 49     2455167.0
# 50      419713.0
# 51     3331859.0
# 52    13367298.0
# 53     1444150.0
# 54     1444150.0
# 55      318031.0
# 56     4195682.0
# 57     3497739.0
# 58      937789.0
# 59     2890732.0
# Name: FemalePop, dtype: float64

# %% [markdown]
# ### 10.We forgot to check for duplicates! Use .duplicated() on your census DataFrame to see if we have duplicate rows in there.

# %%
us_census.index=np.arange(len(us_census.index))        #reindexing in acceding order

dp = us_census['State'].duplicated() #Displays same/duplicated rows
us_census[dp]
# Out:
#     Unnamed: 0         State    TotalPop   Hispanic      White      Black  \
# 9          0.0       Georgia  10006693.0   8.418242  54.286304  32.088299
# 15         0.0          Iowa   3093526.0   5.303645  87.719681   3.256987
# 24         0.0       issouri   6045448.0   4.037248  77.508072  14.122118
# 29         0.0    New Jersey   8904413.0  18.749500  56.488762  14.387862
# 34         0.0          Ohio  11575977.0   3.672084  75.903061  16.207277
# 40         0.0  Rhode Island   1053661.0  13.356667  74.325417   5.682917
# 46         0.0          Utah   2903379.0  13.468376  79.406837   1.017949
#
#       Native     Asian   Pacific        Income        GenderPop    MalePop  \
# 9   0.187583  3.097650  0.046602  50811.082031  4883331_5123362  4883331.0
# 15  0.289793  1.699392  0.055164  53017.753906  1534595_1558931  1534595.0
# 24  0.363329  1.624496  0.101657  49763.988281  2964003_3081445  2964003.0
# 29  0.115335  8.159990  0.031319  76581.085938  4343027_4561386  4343027.0
# 34  0.168888  1.621081  0.022645  49655.250000  5662893_5913084  5662893.0
# 40  0.346250  3.247500  0.035833  59125.269531    510388_543273   510388.0
# 46  1.081367  2.196068  0.825983  63488.917969  1459229_1444150  1459229.0
#
#     FemalePop
# 9   5123362.0
# 15  1558931.0
# 24  3081445.0
# 29  4561386.0
# 34  5913084.0
# 40   543273.0
# 46  1444150.0

# %% [markdown]
# ### 11. Drop those duplicates using the .drop_duplicates() function.

# %%
us_census.drop_duplicates(subset='State',inplace=True)#Drop Duplicated rows
#us_census['State'].duplicated().any()

# %% [markdown]
# ### 12.Make the scatterplot again. Now, it should be perfect! Your job is secure, for now.

# %%
# Again Making scatter plat
plt.scatter(us_census.FemalePop, us_census.Income, c='red')
plt.show()

# %% [markdown]
# ### 13. How, your boss wants you to make a bunch of histograms out of the race data that you have. Look at the .columns again to see what the race categories are.

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop', 'MalePop',
#        'FemalePop'],
#       dtype='object')

# %% [markdown]
# ###  14.T ry to make a histogram for each one!  You will have to get the columns into numerical format, and those percentage signs will have to go.  Don’t forget to fill the nan values with something that makes sense! You probably dropped the duplicate rows when making your last graph, but it couldn’t hurt to check for duplicates again.

# %%
us_census['Pacific'].fillna(us_census['Pacific'].mean(),inplace=True)
##df.drop(['Unnamed: 0','GenderPop'], axis=1, inplace=True)    #droping unnecessary column
#us_census.isna().any()
#us_census.duplicated().any()

# %%
#histogram for 'Hispanic'
plt.hist([us_census.Hispanic,us_census.White,us_census.Black,us_census.Native,us_census.Asian,us_census.Pacific], 
         color=['red','green','blue','grey','yellow','brown'],
        label=['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific'])
plt.legend(loc='best')
plt.xlabel('Races')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Part-2

# %% [markdown]
# ### 1.Data for all of the locations of Petal Power is in the file inventory.csv. Load the data into a DataFrame called inventory

# %%
inventory = pd.read_csv('inventory.csv')    #Loading data from csv file to Pandas DF

# %% [markdown]
# ### 2. Inspect the first 10 rows of inventory.

# %%
inventory.head(10)                #Inspecting first 10 rows
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %% [markdown]
# ### 3. The first 10 rows represent data from your Staten Island location. Select these rows and save them to staten_island.

# %%
staten_island = inventory[:10]         #Saved first 10 rows in a variable

# %% [markdown]
# ### 4. A customer just emailed you asking what products are sold at your Staten Island location. Select the column product_description from staten_island and save it to the variable product_reques

# %%
product_request = staten_island['product_description']

# %% [markdown]
# ### 5. Another customer emails to ask what types of seeds are sold at the Brooklyn location. Select all rows where location is equal to Brooklyn and product_type is equal to seeds and save them to the variable seed_request

# %%
np.where((inventory['location'] == 'Brooklyn') & (inventory['product_type'] == 'seeds'))
# Out:
# (array([10, 11, 12], dtype=int64),)

# %%
#Geting rows where location is 'brooklyn' and product type is 'seed'
seed_request = inventory.loc[np.where((inventory['location'] == 'Brooklyn') & (inventory['product_type'] == 'seeds'))]

# %% [markdown]
# ### 6. Add a column to inventory called in_stock which is True if quantity is greater than 0 and False if quantity equals 0.

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# 11       Brooklyn         seeds                  calla lily         0  19.99
# 12       Brooklyn         seeds                      tomato         0  13.99
# 13       Brooklyn  garden tools                        rake        15  13.99
# 14       Brooklyn  garden tools                 wheelbarrow        82  89.99
# 15       Brooklyn  garden tools                       spade        36  19.99
# 16       Brooklyn  pest_control               insect killer        80  12.99
# 17       Brooklyn  pest_control                 weed killer        76  23.99
# 18       Brooklyn       planter  20 inch terracotta planter         5  17.99
# 19       Brooklyn       planter      8 inch plastic planter        26   3.99
# 20         Queens         seeds                       daisy        57   6.99
# 21         Queens         seeds                  calla lily        95  19.99
# 22         Queens         seeds                      tomato        45  13.99
# 23         Queens  garden tools                        rake        21  13.99
# 24         Queens  garden tools                 wheelbarrow        98  89.99
# 25         Queens  garden tools                       spade        26  19.99
# 26         Queens  pest_control               insect killer         0  12.99
# 27         Queens  pest_control                 weed killer        16  23.99
# 28         Queens       planter  20 inch terracotta planter        87  17.99
#
#     in_stock
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
# 5       True
# 6       True
# 7       True
# 8      False
# 9       True
# 10      True
# 11     False
# 12     False
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26     False
# 27      True
# 28      True

# %%
inventory['quantity'].head()
# Out:
# 0     4
# 1    46
# 2    85
# 3     4
# 4     0
# Name: quantity, dtype: int64

# %%
fun_c = lambda x: True if x>0 else False

# %%
#Creating new column. Its value is 'True' if value in quantity column is greater than zero other wise it is 'False'
inventory['in_stock'] = inventory['quantity'].apply(fun_c)

# %% [markdown]
# ### 7. Petal Power wants to know how valuable their current inventory is. Create a column called total_value that is equal to price multiplied by quantity.

# %%
#Creating new column whoes value = product of price and quantity of product
inventory['total_value'] = inventory['price'] * inventory['quantity']

# %% [markdown]
# #### 8. The Marketing department wants a complete description of each product for their catalog.The following lambda function combines product_type and product_description into a single string:
# combine_lambda = lambda row: \
#     '{} - {}'.format(row.product_type,
#                      row.product_description)
# Paste this function into script.py.

# %%
def new_1(first_value, second_value):
    return first_value + second_value

# %%
new_1(5,6)
# Out:
# 11

# %%
new_2 = lambda first_val,second_val: first_val + second_val

# %%
new_2(5,6)
# Out:
# 11

# %%
combine_lambda_1 = lambda row: row.product_type + "-" + row.product_description

# %%
pd.DataFrame({'product_type':'new_style', "product_description":'second_style'},index=[100])
# Out:
#     product_type product_description
# 100    new_style        second_style

# %%
combine_lambda_1(pd.DataFrame({'product_type':'new_style', "product_description":'second_style'},index=[0]))
# Out:
# 0    new_style-second_style
# dtype: object

# %%
combine_lambda = lambda row: '{} - {}'.format(row.product_type, row.product_description)   #Given script

# %% [markdown]
# ### 9. Using combine_lambda, create a new column in inventory called full_description that has the complete description of each product.

# %%
a = 'I have {} cars whos value is {}'.format(5,6666)

# %%
a
# Out:
# 'I have 5 cars whos value is 6666'

# %%
a.format(4,500000)
# Out:
# 'I have 4 cars whos value is 500000'

# %%
inventory['full_description'] = inventory[['product_type','product_description']].apply(combine_lambda, axis=1) #Created new column form the given script 
#inventory

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# 11       Brooklyn         seeds                  calla lily         0  19.99
# 12       Brooklyn         seeds                      tomato         0  13.99
# 13       Brooklyn  garden tools                        rake        15  13.99
# 14       Brooklyn  garden tools                 wheelbarrow        82  89.99
# 15       Brooklyn  garden tools                       spade        36  19.99
# 16       Brooklyn  pest_control               insect killer        80  12.99
# 17       Brooklyn  pest_control                 weed killer        76  23.99
# 18       Brooklyn       planter  20 inch terracotta planter         5  17.99
# 19       Brooklyn       planter      8 inch plastic planter        26   3.99
# 20         Queens         seeds                       daisy        57   6.99
# 21         Queens         seeds                  calla lily        95  19.99
# 22         Queens         seeds                      tomato        45  13.99
# 23         Queens  garden tools                        rake        21  13.99
# 24         Queens  garden tools                 wheelbarrow        98  89.99
# 25         Queens  garden tools                       spade        26  19.99
# 26         Queens  pest_control               insect killer         0  12.99
# 27         Queens  pest_control                 weed killer        16  23.99
# 28         Queens       planter  20 inch terracotta planter        87  17.99
#
#     in_stock  total_value                      full_description
# 0       True        27.96                         seeds - daisy
# 1       True       919.54                    seeds - calla lily
# 2       True      1189.15                        seeds - tomato
# 3       True        55.96                   garden tools - rake
# 4      False         0.00            garden tools - wheelbarrow
# 5       True      1859.07                  garden tools - spade
# 6       True       961.26          pest_control - insect killer
# 7       True       191.92            pest_control - weed killer
# 8      False         0.00  planter - 20 inch terracotta planter
# 9       True       211.47      planter - 8 inch plastic planter
# 10      True       349.50                         seeds - daisy
# 11     False         0.00                    seeds - calla lily
# 12     False         0.00                        seeds - tomato
# 13      True       209.85                   garden tools - rake
# 14      True      7379.18            garden tools - wheelbarrow
# 15      True       719.64                  garden tools - spade
# 16      True      1039.20          pest_control - insect killer
# 17      True      1823.24            pest_control - weed killer
# 18      True        89.95  planter - 20 inch terracotta planter
# 19      True       103.74      planter - 8 inch plastic planter
# 20      True       398.43                         seeds - daisy
# 21      True      1899.05                    seeds - calla lily
# 22      True       629.55                        seeds - tomato
# 23      True       293.79                   garden tools - rake
# 24      True      8819.02            garden tools - wheelbarrow
# 25      True       519.74                  garden tools - spade
# 26     False         0.00          pest_control - insect killer
# 27      True       383.84            pest_control - weed killer
# 28      True      1565.13  planter - 20 inch terracotta planter

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# 11       Brooklyn         seeds                  calla lily         0  19.99
# 12       Brooklyn         seeds                      tomato         0  13.99
# 13       Brooklyn  garden tools                        rake        15  13.99
# 14       Brooklyn  garden tools                 wheelbarrow        82  89.99
# 15       Brooklyn  garden tools                       spade        36  19.99
# 16       Brooklyn  pest_control               insect killer        80  12.99
# 17       Brooklyn  pest_control                 weed killer        76  23.99
# 18       Brooklyn       planter  20 inch terracotta planter         5  17.99
# 19       Brooklyn       planter      8 inch plastic planter        26   3.99
# 20         Queens         seeds                       daisy        57   6.99
# 21         Queens         seeds                  calla lily        95  19.99
# 22         Queens         seeds                      tomato        45  13.99
# 23         Queens  garden tools                        rake        21  13.99
# 24         Queens  garden tools                 wheelbarrow        98  89.99
# 25         Queens  garden tools                       spade        26  19.99
# 26         Queens  pest_control               insect killer         0  12.99
# 27         Queens  pest_control                 weed killer        16  23.99
# 28         Queens       planter  20 inch terracotta planter        87  17.99
#
#     in_stock  total_value                      full_description
# 0       True        27.96                         seeds - daisy
# 1       True       919.54                    seeds - calla lily
# 2       True      1189.15                        seeds - tomato
# 3       True        55.96                   garden tools - rake
# 4      False         0.00            garden tools - wheelbarrow
# 5       True      1859.07                  garden tools - spade
# 6       True       961.26          pest_control - insect killer
# 7       True       191.92            pest_control - weed killer
# 8      False         0.00  planter - 20 inch terracotta planter
# 9       True       211.47      planter - 8 inch plastic planter
# 10      True       349.50                         seeds - daisy
# 11     False         0.00                    seeds - calla lily
# 12     False         0.00                        seeds - tomato
# 13      True       209.85                   garden tools - rake
# 14      True      7379.18            garden tools - wheelbarrow
# 15      True       719.64                  garden tools - spade
# 16      True      1039.20          pest_control - insect killer
# 17      True      1823.24            pest_control - weed killer
# 18      True        89.95  planter - 20 inch terracotta planter
# 19      True       103.74      planter - 8 inch plastic planter
# 20      True       398.43                         seeds - daisy
# 21      True      1899.05                    seeds - calla lily
# 22      True       629.55                        seeds - tomato
# 23      True       293.79                   garden tools - rake
# 24      True      8819.02            garden tools - wheelbarrow
# 25      True       519.74                  garden tools - spade
# 26     False         0.00          pest_control - insect killer
# 27      True       383.84            pest_control - weed killer
# 28      True      1565.13  planter - 20 inch terracotta planter
