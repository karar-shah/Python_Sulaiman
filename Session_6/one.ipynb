# %% [markdown]
# # Reading and writing Data

# %% [markdown]
# #### Reading files

# %%
import pandas as pd

# %%
df = pd.read_csv("covid19_dataset.csv")
df.head()
# Out:
#    Serial Number        Date Province/State         Country      Last Update  \
# 0              1  22/01/2020            NaN           Japan  1/22/2020 12:00
# 1              2  22/01/2020            NaN        Thailand  1/22/2020 12:00
# 2              3  22/01/2020            NaN     South Korea  1/22/2020 12:00
# 3              4  23/01/2020          Anhui  Mainland China  1/23/2020 12:00
# 4              5  23/01/2020      Hong Kong       Hong Kong  1/23/2020 12:00
#
#    Confirmed  Deaths  Recovered
# 0          2       0          0
# 1          2       0          0
# 2          1       0          0
# 3          9       0          0
# 4          2       0          0

# %% [markdown]
# #### used read_table and specified the delimiter

# %%
df = pd.read_table("covid19_dataset.csv", sep=',')
df.head()
# Out:
#    Serial Number        Date Province/State         Country      Last Update  \
# 0              1  22/01/2020            NaN           Japan  1/22/2020 12:00
# 1              2  22/01/2020            NaN        Thailand  1/22/2020 12:00
# 2              3  22/01/2020            NaN     South Korea  1/22/2020 12:00
# 3              4  23/01/2020          Anhui  Mainland China  1/23/2020 12:00
# 4              5  23/01/2020      Hong Kong       Hong Kong  1/23/2020 12:00
#
#    Confirmed  Deaths  Recovered
# 0          2       0          0
# 1          2       0          0
# 2          1       0          0
# 3          9       0          0
# 4          2       0          0

# %% [markdown]
# #### allow pandas to assign default column names, or you can specify names yourself

# %%
df = pd.read_csv("covid19_dataset.csv", header=None)
df.head()
# Out:
#                0           1               2               3                4  \
# 0  Serial Number        Date  Province/State         Country      Last Update
# 1              1  22/01/2020              NU           Japan  1/22/2020 12:00
# 2              2  22/01/2020              NU              NU  1/22/2020 12:00
# 3              3          NU              NU     South Korea  1/22/2020 12:00
# 4              4  23/01/2020           Anhui  Mainland China  1/23/2020 12:00
#
#            5       6          7
# 0  Confirmed  Deaths  Recovered
# 1          2       0          0
# 2         NU       0          0
# 3          1       0          0
# 4          9       0          0

# %%
df.columns =['a','b','c','d','e','f','h','j']

# %%
df
# Out:
#                  a           b                             c               d  \
# 0    Serial Number        Date                Province/State         Country
# 1                1  22/01/2020                            NU           Japan
# 2                2  22/01/2020                            NU              NU
# 3                3          NU                            NU     South Korea
# 4                4  23/01/2020                         Anhui  Mainland China
# ..             ...         ...                           ...             ...
# 629            629  15/02/2020                           NaN           Nepal
# 630            630  15/02/2020                           NaN       Sri Lanka
# 631            631  15/02/2020                           NaN          Sweden
# 632            632  16/02/2020  Diamond Princess cruise ship          Others
# 633            633  16/02/2020                           NaN       Singapore
#
#                     e          f       h          j
# 0         Last Update  Confirmed  Deaths  Recovered
# 1     1/22/2020 12:00          2       0          0
# 2     1/22/2020 12:00         NU       0          0
# 3     1/22/2020 12:00          1       0          0
# 4     1/23/2020 12:00          9       0          0
# ..                ...        ...     ...        ...
# 629  12/02/2020 14:43          1       0          1
# 630  08/02/2020 03:43          1       0          1
# 631  01/02/2020 02:13          1       0          0
# 632  16/02/2020 03:43        355       0          0
# 633  16/02/2020 16:23         75       0         18
#
# [634 rows x 8 columns]

# %%
df = pd.read_csv("covid19_dataset.csv", names=['a','b','c','d','e','f','h'])
df.head()
# Out:
#                         a               b               c                d  \
# Serial Number        Date  Province/State         Country      Last Update
# 1              22/01/2020             NaN           Japan  1/22/2020 12:00
# 2              22/01/2020             NaN        Thailand  1/22/2020 12:00
# 3              22/01/2020             NaN     South Korea  1/22/2020 12:00
# 4              23/01/2020           Anhui  Mainland China  1/23/2020 12:00
#
#                        e       f          h
# Serial Number  Confirmed  Deaths  Recovered
# 1                      2       0          0
# 2                      2       0          0
# 3                      1       0          0
# 4                      9       0          0

# %% [markdown]
# #### column to be the index of the returned DataFrame

# %%
df = pd.read_csv("covid19_dataset.csv", index_col='Date')
df.head()
# Out:
#             Serial Number Province/State         Country      Last Update  \
# Date
# 22/01/2020              1            NaN           Japan  1/22/2020 12:00
# 22/01/2020              2            NaN        Thailand  1/22/2020 12:00
# 22/01/2020              3            NaN     South Korea  1/22/2020 12:00
# 23/01/2020              4          Anhui  Mainland China  1/23/2020 12:00
# 23/01/2020              5      Hong Kong       Hong Kong  1/23/2020 12:00
#
#             Confirmed  Deaths  Recovered
# Date
# 22/01/2020          2       0          0
# 22/01/2020          2       0          0
# 22/01/2020          1       0          0
# 23/01/2020          9       0          0
# 23/01/2020          2       0          0

# %% [markdown]
# #### you can skip the first, third, and fourth rows of a file with skiprows:

# %%
df = pd.read_csv("covid19_dataset.csv", skiprows=[0,2,3])
df.head()
# Out:
#    1  22/01/2020 Unnamed: 2           Japan  1/22/2020 12:00  2  0  0.1
# 0  4  23/01/2020      Anhui  Mainland China  1/23/2020 12:00  9  0    0
# 1  5  23/01/2020  Hong Kong       Hong Kong  1/23/2020 12:00  2  0    0
# 2  6  23/01/2020      Macau           Macau  1/23/2020 12:00  2  0    0
# 3  7  23/01/2020     Taiwan          Taiwan  1/23/2020 12:00  1  0    0
# 4  8  23/01/2020        NaN           Japan  1/23/2020 12:00  1  0    0

# %% [markdown]
# #### The na_values option can take either a list or set of strings to consider missingvalues:

# %%
df = pd.read_csv("covid19_dataset.csv")
df.head()
# Out:
#    Serial Number        Date Province/State         Country      Last Update  \
# 0              1  22/01/2020             NU           Japan  1/22/2020 12:00
# 1              2  22/01/2020             NU              NU  1/22/2020 12:00
# 2              3          NU             NU     South Korea  1/22/2020 12:00
# 3              4  23/01/2020          Anhui  Mainland China  1/23/2020 12:00
# 4              5  23/01/2020      Hong Kong       Hong Kong  1/23/2020 12:00
#
#   Confirmed  Deaths  Recovered
# 0         2       0          0
# 1        NU       0          0
# 2         1       0          0
# 3         9       0          0
# 4         2       0          0

# %%
df = pd.read_csv("covid19_dataset.csv", na_values=['NU'])
df.head()
# Out:
#    Serial Number        Date Province/State         Country      Last Update  \
# 0              1  22/01/2020            NaN           Japan  1/22/2020 12:00
# 1              2  22/01/2020            NaN             NaN  1/22/2020 12:00
# 2              3         NaN            NaN     South Korea  1/22/2020 12:00
# 3              4  23/01/2020          Anhui  Mainland China  1/23/2020 12:00
# 4              5  23/01/2020      Hong Kong       Hong Kong  1/23/2020 12:00
#
#    Confirmed  Deaths  Recovered
# 0        2.0       0          0
# 1        NaN       0          0
# 2        1.0       0          0
# 3        9.0       0          0
# 4        2.0       0          0

# %% [markdown]
# ##### If you want to only read a small number of rows (avoiding reading the entire file),specify that with nrows:

# %%
pd.read_csv('covid19_dataset.csv', nrows=3)
# Out:
#    Serial Number        Date Province/State      Country      Last Update  \
# 0              1  22/01/2020             NU        Japan  1/22/2020 12:00
# 1              2  22/01/2020             NU           NU  1/22/2020 12:00
# 2              3          NU             NU  South Korea  1/22/2020 12:00
#
#   Confirmed  Deaths  Recovered
# 0         2       0          0
# 1        NU       0          0
# 2         1       0          0

# %% [markdown]
# # Writing Data to Text Format
# **can also be exported to a delimited format**

# %%
df.to_csv('out.csv')

# %%
df.to_csv('out_1.csv', index=False, header=False)

# %% [markdown]
# # Reading Microsoft Excel Files

# %%
xlsx = pd.read_excel('work.xlsx','Sheet1', index_col='CustomerID')
xlsx.head()
# Out:
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1             Male   19                  15                      39
# 2             Male   21                  15                      81
# 3           Female   20                  16                       6
# 4           Female   23                  16                      77
# 5           Female   31                  17                      40
